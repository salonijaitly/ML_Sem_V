# %% [markdown]
# <a href="https://colab.research.google.com/github/salonijaitly/ML_Sem_V/blob/master/ML_03_J070_240720.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exp 3. Python for data visualization

# %%
import numpy as np # useful for many scientific computing in Python
import pandas as pd # primary data structure library
 
# !conda install -c anaconda xlrd --yes
 
df_can = pd.read_excel('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx',
 sheet_name='Canada by Citizenship',
 skiprows=range(20),
 skipfooter=2)
 
print ('Data read into a pandas dataframe!')
# Out:
# /bin/bash: conda: command not found
# Data read into a pandas dataframe!

# %%
df_can
# Out:
#            Type    Coverage          OdName  AREA  ...  2010  2011  2012  2013
# 0    Immigrants  Foreigners     Afghanistan   935  ...  1758  2203  2635  2004
# 1    Immigrants  Foreigners         Albania   908  ...   561   539   620   603
# 2    Immigrants  Foreigners         Algeria   903  ...  4752  4325  3774  4331
# 3    Immigrants  Foreigners  American Samoa   909  ...     0     0     0     0
# 4    Immigrants  Foreigners         Andorra   908  ...     0     0     1     1
# ..          ...         ...             ...   ...  ...   ...   ...   ...   ...
# 190  Immigrants  Foreigners        Viet Nam   935  ...  1942  1723  1731  2112
# 191  Immigrants  Foreigners  Western Sahara   903  ...     0     0     0     0
# 192  Immigrants  Foreigners           Yemen   935  ...   211   160   174   217
# 193  Immigrants  Foreigners          Zambia   903  ...   102    69    46    59
# 194  Immigrants  Foreigners        Zimbabwe   903  ...   494   434   437   407
#
# [195 rows x 43 columns]

# %%
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA  ...  2010  2011  2012  2013
# 0  Immigrants  Foreigners     Afghanistan   935  ...  1758  2203  2635  2004
# 1  Immigrants  Foreigners         Albania   908  ...   561   539   620   603
# 2  Immigrants  Foreigners         Algeria   903  ...  4752  4325  3774  4331
# 3  Immigrants  Foreigners  American Samoa   909  ...     0     0     0     0
# 4  Immigrants  Foreigners         Andorra   908  ...     0     0     1     1
#
# [5 rows x 43 columns]

# %%
df_can.tail()
# Out:
#            Type    Coverage          OdName  AREA  ...  2010  2011  2012  2013
# 190  Immigrants  Foreigners        Viet Nam   935  ...  1942  1723  1731  2112
# 191  Immigrants  Foreigners  Western Sahara   903  ...     0     0     0     0
# 192  Immigrants  Foreigners           Yemen   935  ...   211   160   174   217
# 193  Immigrants  Foreigners          Zambia   903  ...   102    69    46    59
# 194  Immigrants  Foreigners        Zimbabwe   903  ...   494   434   437   407
#
# [5 rows x 43 columns]

# %%
df_can.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 43 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Type      195 non-null    object
#  1   Coverage  195 non-null    object
#  2   OdName    195 non-null    object
#  3   AREA      195 non-null    int64
#  4   AreaName  195 non-null    object
#  5   REG       195 non-null    int64
#  6   RegName   195 non-null    object
#  7   DEV       195 non-null    int64
#  8   DevName   195 non-null    object
#  9   1980      195 non-null    int64
#  10  1981      195 non-null    int64
#  11  1982      195 non-null    int64
#  12  1983      195 non-null    int64
#  13  1984      195 non-null    int64
#  14  1985      195 non-null    int64
#  15  1986      195 non-null    int64
#  16  1987      195 non-null    int64
#  17  1988      195 non-null    int64
#  18  1989      195 non-null    int64
#  19  1990      195 non-null    int64
#  20  1991      195 non-null    int64
#  21  1992      195 non-null    int64
#  22  1993      195 non-null    int64
#  23  1994      195 non-null    int64
#  24  1995      195 non-null    int64
#  25  1996      195 non-null    int64
#  26  1997      195 non-null    int64
#  27  1998      195 non-null    int64
#  28  1999      195 non-null    int64
#  29  2000      195 non-null    int64
#  30  2001      195 non-null    int64
#  31  2002      195 non-null    int64
#  32  2003      195 non-null    int64
#  33  2004      195 non-null    int64
#  34  2005      195 non-null    int64
#  35  2006      195 non-null    int64
#  36  2007      195 non-null    int64
#  37  2008      195 non-null    int64
#  38  2009      195 non-null    int64
#  39  2010      195 non-null    int64
#  40  2011      195 non-null    int64
#  41  2012      195 non-null    int64
#  42  2013      195 non-null    int64
# dtypes: int64(37), object(6)
# memory usage: 65.6+ KB

# %%
df_can.columns
# Out:
# Index([    'Type', 'Coverage',   'OdName',     'AREA', 'AreaName',      'REG',
#         'RegName',      'DEV',  'DevName',       1980,       1981,       1982,
#              1983,       1984,       1985,       1986,       1987,       1988,
#              1989,       1990,       1991,       1992,       1993,       1994,
#              1995,       1996,       1997,       1998,       1999,       2000,
#              2001,       2002,       2003,       2004,       2005,       2006,
#              2007,       2008,       2009,       2010,       2011,       2012,
#              2013],
#       dtype='object')

# %%
df_can.dtypes
# Out:
# Type        object
# Coverage    object
# OdName      object
# AREA         int64
# AreaName    object
# REG          int64
# RegName     object
# DEV          int64
# DevName     object
# 1980         int64
# 1981         int64
# 1982         int64
# 1983         int64
# 1984         int64
# 1985         int64
# 1986         int64
# 1987         int64
# 1988         int64
# 1989         int64
# 1990         int64
# 1991         int64
# 1992         int64
# 1993         int64
# 1994         int64
# 1995         int64
# 1996         int64
# 1997         int64
# 1998         int64
# 1999         int64
# 2000         int64
# 2001         int64
# 2002         int64
# 2003         int64
# 2004         int64
# 2005         int64
# 2006         int64
# 2007         int64
# 2008         int64
# 2009         int64
# 2010         int64
# 2011         int64
# 2012         int64
# 2013         int64
# dtype: object

# %%
df_can.shape
# Out:
# (195, 43)

# %%
df_can.drop(['AREA','REG','Type','Coverage','DEV'],axis='columns',inplace=True)

# %%
df_can.rename(columns={'OdName':'Country','AreaName':'Continent','RegName':'Region','DevName':'DevStatus'},inplace=True)

# %%
df_can['Total_immigration']=df_can.sum(axis='columns')

df_can
# Out:
#             Country Continent  ...  2013 Total_immigration
# 0       Afghanistan      Asia  ...  2004             58639
# 1           Albania    Europe  ...   603             15699
# 2           Algeria    Africa  ...  4331             69439
# 3    American Samoa   Oceania  ...     0                 6
# 4           Andorra    Europe  ...     1                15
# ..              ...       ...  ...   ...               ...
# 190        Viet Nam      Asia  ...  2112             97146
# 191  Western Sahara    Africa  ...     0                 2
# 192           Yemen      Asia  ...   217              2985
# 193          Zambia    Africa  ...    59              1677
# 194        Zimbabwe    Africa  ...   407              8598
#
# [195 rows x 39 columns]

# %% [markdown]
# applying conditions on a dataframe
#
# Filtering the data with Continent= Asia and DevStatus 'Developing Regions'

# %%
df_can[(df_can['Continent']=='Asia')&(df_can['DevStatus']=='Developing regions')]
# Out:
#                                             Country  ... Total_immigration
# 0                                       Afghanistan  ...             58639
# 8                                           Armenia  ...              3310
# 11                                       Azerbaijan  ...              2649
# 13                                          Bahrain  ...               475
# 14                                       Bangladesh  ...             65568
# 20                                           Bhutan  ...              5876
# 25                                Brunei Darussalam  ...               600
# 30                                         Cambodia  ...              6538
# 36                                            China  ...            659962
# 37   China, Hong Kong Special Administrative Region  ...              9327
# 38       China, Macao Special Administrative Region  ...               284
# 46                                           Cyprus  ...              1126
# 48            Democratic People's Republic of Korea  ...               388
# 66                                          Georgia  ...              2068
# 79                                            India  ...            691904
# 80                                        Indonesia  ...             13150
# 81                       Iran (Islamic Republic of)  ...            175923
# 82                                             Iraq  ...             69789
# 84                                           Israel  ...             66508
# 88                                           Jordan  ...             35406
# 89                                       Kazakhstan  ...              8490
# 92                                           Kuwait  ...              2025
# 93                                       Kyrgyzstan  ...              2353
# 94                 Lao People's Democratic Republic  ...              1089
# 96                                          Lebanon  ...            115359
# 105                                        Malaysia  ...             24417
# 106                                        Maldives  ...                30
# 114                                        Mongolia  ...               952
# 118                                         Myanmar  ...              9245
# 121                                           Nepal  ...             10222
# 129                                            Oman  ...               224
# 130                                        Pakistan  ...            241600
# 136                                     Philippines  ...            511391
# 139                                           Qatar  ...               157
# 140                               Republic of Korea  ...            142581
# 151                                    Saudi Arabia  ...              3425
# 156                                       Singapore  ...             14579
# 162                                       Sri Lanka  ...            148358
# 163                              State of Palestine  ...              6512
# 169                            Syrian Arab Republic  ...             31485
# 170                                      Tajikistan  ...               503
# 171                                        Thailand  ...              9174
# 177                                          Turkey  ...             31781
# 178                                    Turkmenistan  ...               310
# 182                            United Arab Emirates  ...               836
# 187                                      Uzbekistan  ...              3368
# 190                                        Viet Nam  ...             97146
# 192                                           Yemen  ...              2985
#
# [48 rows x 39 columns]

# %%
df_can[['Country',1980,1981]]
# Out:
#             Country  1980  1981
# 0       Afghanistan    16    39
# 1           Albania     1     0
# 2           Algeria    80    67
# 3    American Samoa     0     1
# 4           Andorra     0     0
# ..              ...   ...   ...
# 190        Viet Nam  1191  1829
# 191  Western Sahara     0     0
# 192           Yemen     1     2
# 193          Zambia    11    17
# 194        Zimbabwe    72   114
#
# [195 rows x 3 columns]

# %%
df_can.Country
# Out:
# 0         Afghanistan
# 1             Albania
# 2             Algeria
# 3      American Samoa
# 4             Andorra
#             ...
# 190          Viet Nam
# 191    Western Sahara
# 192             Yemen
# 193            Zambia
# 194          Zimbabwe
# Name: Country, Length: 195, dtype: object

# %%
type(df_can.Country)
# Out:
# pandas.core.series.Series

# %%
type(df_can[['Country',1980,1981]])
# Out:
# pandas.core.frame.DataFrame

# %%
df_can['Continent']
# Out:
# 0         Asia
# 1       Europe
# 2       Africa
# 3      Oceania
# 4       Europe
#         ...
# 190       Asia
# 191     Africa
# 192       Asia
# 193     Africa
# 194     Africa
# Name: Continent, Length: 195, dtype: object

# %%
df_can.index
# Out:
# RangeIndex(start=0, stop=195, step=1)

# %%
df_can.set_index('Country', inplace=True)

df_can.head()
# Out:
#                Continent           Region  ...  2013  Total_immigration
# Country                                    ...
# Afghanistan         Asia    Southern Asia  ...  2004              58639
# Albania           Europe  Southern Europe  ...   603              15699
# Algeria           Africa  Northern Africa  ...  4331              69439
# American Samoa   Oceania        Polynesia  ...     0                  6
# Andorra           Europe  Southern Europe  ...     1                 15
#
# [5 rows x 38 columns]

# %%
df_can.loc['India']
# Out:
# Continent                          Asia
# Region                    Southern Asia
# DevStatus            Developing regions
# 1980                               8880
# 1981                               8670
# 1982                               8147
# 1983                               7338
# 1984                               5704
# 1985                               4211
# 1986                               7150
# 1987                              10189
# 1988                              11522
# 1989                              10343
# 1990                              12041
# 1991                              13734
# 1992                              13673
# 1993                              21496
# 1994                              18620
# 1995                              18489
# 1996                              23859
# 1997                              22268
# 1998                              17241
# 1999                              18974
# 2000                              28572
# 2001                              31223
# 2002                              31889
# 2003                              27155
# 2004                              28235
# 2005                              36210
# 2006                              33848
# 2007                              28742
# 2008                              28261
# 2009                              29456
# 2010                              34235
# 2011                              27509
# 2012                              30933
# 2013                              33087
# Total_immigration                691904
# Name: India, dtype: object

# %%
df_can.iloc[87]
# Out:
# Continent                         Asia
# Region                    Eastern Asia
# DevStatus            Developed regions
# 1980                               701
# 1981                               756
# 1982                               598
# 1983                               309
# 1984                               246
# 1985                               198
# 1986                               248
# 1987                               422
# 1988                               324
# 1989                               494
# 1990                               379
# 1991                               506
# 1992                               605
# 1993                               907
# 1994                               956
# 1995                               826
# 1996                               994
# 1997                               924
# 1998                               897
# 1999                              1083
# 2000                              1010
# 2001                              1092
# 2002                               806
# 2003                               817
# 2004                               973
# 2005                              1067
# 2006                              1212
# 2007                              1250
# 2008                              1284
# 2009                              1194
# 2010                              1168
# 2011                              1265
# 2012                              1214
# 2013                               982
# Total_immigration                27707
# Name: Japan, dtype: object

# %%
df_can.loc['India',1980]
# Out:
# 8880

# %%
print(df_can.loc['Japan',2000])
# Out:
# 1010

# %%
print(df_can.iloc[12,12])
# Out:
# 32

# %%
#convert columns names to string
#map - syntax(function, collection)
#apply function to each element of the collection - equivalent apply, mapply,sapply,lapply functions of R

df_can.columns = list(map(str,df_can.columns))

# %%
df_can.columns
# Out:
# Index(['Continent', 'Region', 'DevStatus', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
#        '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', 'Total_immigration'],
#       dtype='object')

# %% [markdown]
# Finding all data having Continent as Asia

# %%
condition = df_can['Continent'] == 'Asia'
df_can[condition]
# Out:
#                                                Continent  ... Total_immigration
# Country                                                   ...
# Afghanistan                                         Asia  ...             58639
# Armenia                                             Asia  ...              3310
# Azerbaijan                                          Asia  ...              2649
# Bahrain                                             Asia  ...               475
# Bangladesh                                          Asia  ...             65568
# Bhutan                                              Asia  ...              5876
# Brunei Darussalam                                   Asia  ...               600
# Cambodia                                            Asia  ...              6538
# China                                               Asia  ...            659962
# China, Hong Kong Special Administrative Region      Asia  ...              9327
# China, Macao Special Administrative Region          Asia  ...               284
# Cyprus                                              Asia  ...              1126
# Democratic People's Republic of Korea               Asia  ...               388
# Georgia                                             Asia  ...              2068
# India                                               Asia  ...            691904
# Indonesia                                           Asia  ...             13150
# Iran (Islamic Republic of)                          Asia  ...            175923
# Iraq                                                Asia  ...             69789
# Israel                                              Asia  ...             66508
# Japan                                               Asia  ...             27707
# Jordan                                              Asia  ...             35406
# Kazakhstan                                          Asia  ...              8490
# Kuwait                                              Asia  ...              2025
# Kyrgyzstan                                          Asia  ...              2353
# Lao People's Democratic Republic                    Asia  ...              1089
# Lebanon                                             Asia  ...            115359
# Malaysia                                            Asia  ...             24417
# Maldives                                            Asia  ...                30
# Mongolia                                            Asia  ...               952
# Myanmar                                             Asia  ...              9245
# Nepal                                               Asia  ...             10222
# Oman                                                Asia  ...               224
# Pakistan                                            Asia  ...            241600
# Philippines                                         Asia  ...            511391
# Qatar                                               Asia  ...               157
# Republic of Korea                                   Asia  ...            142581
# Saudi Arabia                                        Asia  ...              3425
# Singapore                                           Asia  ...             14579
# Sri Lanka                                           Asia  ...            148358
# State of Palestine                                  Asia  ...              6512
# Syrian Arab Republic                                Asia  ...             31485
# Tajikistan                                          Asia  ...               503
# Thailand                                            Asia  ...              9174
# Turkey                                              Asia  ...             31781
# Turkmenistan                                        Asia  ...               310
# United Arab Emirates                                Asia  ...               836
# Uzbekistan                                          Asia  ...              3368
# Viet Nam                                            Asia  ...             97146
# Yemen                                               Asia  ...              2985
#
# [49 rows x 38 columns]

# %% [markdown]
# Filtering all the data with Continent as Asia and no. of immigrants in 2013 being more than 10000

# %%
df_can[(df_can['Continent']=='Asia')&(df_can['2013']>10000)]
# Out:
#                            Continent  ... Total_immigration
# Country                               ...
# China                           Asia  ...            659962
# India                           Asia  ...            691904
# Iran (Islamic Republic of)      Asia  ...            175923
# Pakistan                        Asia  ...            241600
# Philippines                     Asia  ...            511391
#
# [5 rows x 38 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import plotly as px

# %%
years = list(map(str,range(1980,2014)))

years
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %% [markdown]
# Line Plots

# %%
india = df_can.loc['India',years]
india.plot()

# %%
#change the index to integer
india.index = india.index.map(int)

india.plot(kind='line',figsize=(12,9))
plt.title('Immigration from India')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')

#update the plot with correct labels
plt.show()

# %%
india.plot(kind='line',figsize=(12,9))
plt.title('Immigration from India')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')

plt.text(2000, 32000, 'Y2K Revolution')
plt.text(1990,15000,'Recession')
plt.text(1985,10000,'Economic boom')
#update the plot
plt.show()

# %% [markdown]
# Plotting the immigration from China to Canada

# %%
years = list(map(str,range(1980,2014)))
china = df_can.loc['China', years]

# %%
china.plot()

# %%
china.index = china.index.map(int)
china.plot(kind='line',figsize=(9,6))
plt.title('Immigration of China')
plt.xlabel('Years')
plt.ylabel('Immigrants')
plt.text(1990,10000,'Marker')
plt.show()

# %% [markdown]
# Comparing China and India's Immigration Trend

# %%
years = list(map(str,range(1980,2014)))

chinaindia = df_can.loc[['China','India'], years]
new_chinaindia = chinaindia.transpose()
new_chinaindia.plot()

# %%
new_chinaindia.index = new_chinaindia.index.map(int)

new_chinaindia.plot(kind='line',figsize=(9,6))

plt.title('Immigration of China and India')
plt.xlabel('Years')
plt.ylabel('Immigrants')
#plt.text(1990,10000,'Marker')
plt.show()

# %% [markdown]
# Comparing immigration trends of France and Germany

# %%
frager = df_can.loc[['Germany','France'], years]
frager = frager.transpose()
frager.index = frager.index.map(int)

frager.plot(kind='line', figsize = (9,6))
plt.title('Immigration of France and Germany')
plt.xlabel('Years')
plt.ylabel('No. of Immigrants')
plt.show()

# %% [markdown]
# Top 5 countries to send immigrants to Canada

# %%
df_can.sort_values(by='Total_immigration', ascending=False, axis='index', inplace=True)

top5 = df_can.head(5)

top5
# Out:
#                                                    Continent  ... Total_immigration
# Country                                                       ...
# India                                                   Asia  ...            691904
# China                                                   Asia  ...            659962
# United Kingdom of Great Britain and Northern Ir...    Europe  ...            551500
# Philippines                                             Asia  ...            511391
# Pakistan                                                Asia  ...            241600
#
# [5 rows x 38 columns]

# %%
years = list(map(str,range(1980,2014)))
top5_temp = top5[years]

top5_temp = top5_temp.transpose()
top5_temp.plot(figsize=(10,8))

# %% [markdown]
# Plotting Unstacked and Stacked Area charts

# %%
top5_temp.index = top5_temp.index.map(int)

top5_temp.plot(kind="area", stacked=False, figsize=(15,10))

plt.title('Immigration trends in top five countries (1980-2013)')
plt.xlabel('Years')
plt.ylabel('Immigrants count')

plt.show()

# %%
top5_temp.index = top5_temp.index.map(int)

top5_temp.plot(kind="area", stacked=True, figsize=(15,10))

plt.title('Immigration trends in top five countries (1980-2013)')
plt.xlabel('Years')
plt.ylabel('Immigrants count')

plt.show()

# %%
top5_temp.index = top5_temp.index.map(int)

#alpha parameter for transparency - default = 0.5 (range is 0 to 1)

top5_temp.plot(kind="area", stacked=False, figsize=(15,10), alpha=0.25)

plt.title('Immigration trends in top five countries (1980-2013)')
plt.xlabel('Years')
plt.ylabel('Immigrants count')

plt.show()

# %% [markdown]
# Histogram

# %%
df_can['2000'].plot(kind='hist', figsize=(9,6))
#at a particular time period / snapshot of the data
plt.title('Immigration trends in 195 countries in 2000')
plt.xlabel('Number of Immigrants')
plt.ylabel('Number of Countries')

plt.show()

# %% [markdown]
# Immigration trends in 6 selected countries from 1980 to 2013

# %%
years = list(map(str,range(1980,2014)))

df_can.loc[['India','China','Denmark','Norway','France','Germany'], years].transpose().plot.hist()
plt.title('Immigration trends in 6 countries in 1980-2013')
plt.xlabel('Number of Immigrants')
plt.ylabel('Number of Countries')

plt.show()

# %% [markdown]
#  Vertical Bar Plot for Immigration from India to Canada

# %%
india = df_can.loc['India', years]

india.plot(kind='bar', figsize=(15,10))

plt.title('Immigration trends India immigrants from 1980 to 2013')
plt.xlabel('Years')
plt.ylabel('India immigrants from 1980 to 2013')

plt.show()

# %% [markdown]
# With Annotations

# %%
india = df_can.loc['India', years]

india.index = india.index.map(int)


india.plot(kind='bar')

plt.title('Immigration trends India immigrants from 1980 to 2013')
plt.xlabel('Years')
plt.ylabel('India immigrants from 1980 to 2013')

plt.annotate('Increasing trends', xy=(21,35000),  xycoords='data',
            xytext=(4,15000), 
            arrowprops=dict(facecolor='black', shrink=0.05),
            horizontalalignment='left', verticalalignment='top',
             rotation=45
            )

plt.show()

# %%
df_india = df_can.loc['India',years]
df_india.plot(kind='bar', figsize=(10,6))
plt.title("Indian immigration to Canada from 1980 to 2013")
plt.xlabel("Year")
plt.ylabel("Number of immigrants")

plt.annotate('',  #arrow title
             xy=(21,35000), #x,y of arrow head
             xytext=(7,15000), #x, y of arrow tail
             xycoords='data',  #keep unchanged
             arrowprops=dict(arrowstyle='->',color='red') #arrow style with color
             )

plt.annotate('IT Boom', #add text to arrow
             xy=(13,28000),  #x, y of text position
             rotation=40, # counter clockwise rotate text by angle
             xycoords='data', #keep unchanged
             va='top', #position text 
             ha='left') #position text
plt.show()
